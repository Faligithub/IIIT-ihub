# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !ls '/content/gdrive/My Drive
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 2: syntax error: unexpected end of file

# %%
ROOT_DIR= '/content/gdrive/My Drive/Colab Notebooks/IIIT/SHRISHTI-24/Garbage_Identification'

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 709.5/709.5 kB 9.3 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO

#Load a model
model=YOLO('yolov8n.yaml') #Build a new model from scratch

#Use the model
results=model.train(data=os.path.join(ROOT_DIR, "google_colab_config.yaml"), epochs=10) #train the model
# Out:
# Ultralytics YOLOv8.1.11 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# !scp -r /content/runs '/content/gdrive/My Drive/Colab Notebooks/IIIT/SHRISHTI-24/Garbage_Identification'

# %%
drive.flush_and_unmount()
